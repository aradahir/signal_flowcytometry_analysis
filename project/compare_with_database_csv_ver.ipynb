# %%
import json
import pandas as pd
from collections import Counter
import numpy as np
pd.set_option('display.max_rows', 1000)


filename_u = 'Up_PY017.csv'
filename_d = 'Down_PY017.csv'

df_u =  pd.read_csv(filename_u);
df_d =  pd.read_csv(filename_d);
upgene= df_u['gene']
dngene= df_d['gene']

my_list_compare = ['genes']
my_list_compare_w = []
my_list_compare_u = []
type_gene = []

for item_s in upgene:
    my_list_compare_w.append(item_s)
    my_list_compare_u.append(item_s)

for item in dngene:
    my_list_compare_w.append(item)


gene_list = Counter(my_list_compare_w).keys()
gene_count =Counter(my_list_compare_w).values()
gene_cu =Counter(my_list_compare_u).values()


gene = list(gene_list)
genec = list(gene_count)
geneu = list(gene_cu)

gene_a = []

for x in range(0,len(gene_count)):
    if genec[x] != 2:
        if x  <  sum(geneu): 
            type_gene.append('up gene')
            gene_a.append(gene[x])
        else: 
            type_gene.append('down gene')
            gene_a.append(gene[x])
    else:    
        type_gene.append('both')
        gene_a.append(gene[x])

    
df_pd = pd.DataFrame(data = type_gene, columns = ['type'])
df_pd['gene'] = gene_a
df_pd
# Out:
#           type          gene
# 0      up gene       SNORA13
# 1      up gene        C9orf9
# 2      up gene        NLGN4Y
# 3      up gene      KIAA0319
# 4      up gene         GNG13
# 5      up gene      TNFSF13B
# 6      up gene         PLCE1
# 7      up gene          AMZ1
# 8      up gene      SNORD15A
# 9      up gene          QRFP
# 10     up gene          SCGN
# 11     up gene           TEC
# 12     up gene      RPL21P44
# 13     up gene         PRR29
# 14     up gene         TPRXL
# 15     up gene        KCNAB3
# 16     up gene       SNORA28
# 17     up gene         LOXL2
# 18     up gene          NSD1
# 19     up gene          LEF1
# 20     up gene        GAREML
# 21     up gene          NCAN
# 22     up gene          GJC3
# 23     up gene       BCL2L14
# 24     up gene        GLT8D2
# 25     up gene        DNAJA4
# 26     up gene       MIR4690
# 27     up gene      ARHGEF33
# 28     up gene        CARD16
# 29     up gene         OR2B6
# 30     up gene         PBOV1
# 31     up gene      CACNA2D2
# 32     up gene          AQP8
# 33     up gene        DPYSL3
# 34     up gene  LOC100506476
# 35     up gene           RET
# 36     up gene          GJA9
# 37     up gene        LRRC17
# 38     up gene         PTPRM
# 39     up gene        MIR29C
# 40     up gene       MIR106B
# 41     up gene          GRK1
# 42     up gene       MIR1915
# 43     up gene          JPH3
# 44     up gene        CTAGE9
# 45     up gene     HIST1H2AD
# 46     up gene         HTR2B
# 47     up gene         GNAT1
# 48     up gene          NTN3
# 49     up gene    MAMDC2-AS1
# 50     up gene         ARAP3
# 51        both         RAB41
# 52     up gene          CFTR
# 53     up gene       MIR3176
# 54        both         ULBP1
# 55     up gene    ZNF582-AS1
# 56     up gene          AQP7
# 57     up gene         HSPB9
# 58     up gene  SH3PXD2A-AS1
# 59     up gene         SKOR1
# 60     up gene  LOC102724601
# 61     up gene        MIR612
# 62     up gene           BOC
# 63     up gene       MIR4749
# 64     up gene         FOXD4
# 65     up gene         APOC4
# 66     up gene  LOC102723439
# 67     up gene     LOC728024
# 68     up gene         TUSC3
# 69     up gene    KANSL1-AS1
# 70     up gene        MIR140
# 71     up gene       MIR4519
# 72     up gene       MIR4726
# 73     up gene      FAM133CP
# 74     up gene       RCAN3AS
# 75     up gene      ISM1-AS1
# 76     up gene       MIR5088
# 77     up gene     LINC00659
# 78     up gene          FUT1
# 79     up gene       MIR6820
# 80     up gene  LOC101929657
# 81     up gene  LOC101927870
# 82     up gene   MID1IP1-AS1
# 83     up gene          RHOD
# 84     up gene        GSTA7P
# 85     up gene         XIRP2
# 86     up gene         PTGS1
# 87     up gene          MYL1
# 88        both         RLBP1
# 89     up gene         TNNT3
# 90     up gene          A1CF
# 91     up gene        PRSS12
# 92     up gene          MYOT
# 93     up gene         TRPM6
# 94     up gene        MYBPC2
# 95     up gene        LRRTM3
# 96     up gene          AQP9
# 97     up gene        CLPSL2
# 98     up gene       SPATA12
# 99        both          RRAD
# 100       both       MIR8085
# 101    up gene          PRB3
# 102    up gene       WFDC10B
# 103    up gene           CKM
# 104    up gene  LOC102659288
# 105    up gene        MIR424
# 106    up gene     LINC00624
# 107    up gene       SLC26A4
# 108       both      MTRNR2L2
# 109    up gene          MYH2
# 110    up gene        MYBPC1
# 111    up gene      PHOSPHO1
# 112    up gene     LINC00704
# 113    up gene         CSRP3
# 114    up gene        CYP1A1
# 115    up gene          AGXT
# 116    up gene        ADCY10
# 117    up gene       SLC35G2
# 118    up gene          ISL1
# 119       both       FOXD4L1
# 120    up gene     LOC389895
# 121    up gene        TMEM40
# 122    up gene         KCNG3
# 123    up gene          MYH1
# 124    up gene       OLFML2B
# 125       both          SOX5
# 126    up gene        COL1A2
# 127    up gene          IL1A
# 128    up gene       LEPREL2
# 129    up gene  LOC100507091
# 130    up gene        TAS2R3
# 131    up gene         CASQ2
# 132    up gene      MAP1LC3A
# 133    up gene       ANKRD63
# 134    up gene          MYH7
# 135    up gene          MYL3
# 136    up gene     TNFRSF13C
# 137    up gene           SLN
# 138    up gene         ITGA4
# 139    up gene        MIR643
# 140    up gene  LOC101927901
# 141    up gene         TNNC2
# 142    up gene        DNAH12
# 143    up gene       FOXL2NB
# 144    up gene  LOC101928008
# 145    up gene       MIR7112
# 146       both       MIR6857
# 147    up gene    MIR133A1HG
# 148    up gene        DNAJB3
# 149    up gene       FAM159B
# 150    up gene           MPO
# 151    up gene        HIGD1B
# 152    up gene        RSPH4A
# 153    up gene        ADAM22
# 154    up gene       BCL2L15
# 155    up gene       DCSTAMP
# 156    up gene        KLHL30
# 157    up gene         GLIS3
# 158    up gene      C19orf35
# 159    up gene  LOC100128770
# 160    up gene           MPL
# 161    up gene         RGPD1
# 162    up gene         ACAP1
# 163    up gene         GRIK2
# 164       both         F2RL2
# 165    up gene        ANXA10
# 166    up gene         OSCAR
# 167    up gene          PYY2
# 168    up gene         ACTA1
# 169    up gene          WEE2
# 170    up gene         FITM1
# 171    up gene        TUBA3E
# 172    up gene         NFAM1
# 173    up gene         DNAH9
# 174    up gene       CCDC168
# 175    up gene         APBA1
# 176    up gene       SNORD64
# 177    up gene      SLC16A11
# 178    up gene     LINC00999
# 179    up gene         GCNT3
# 180    up gene         SH2D6
# 181    up gene         GGT8P
# 182    up gene          LGI4
# 183    up gene       ZMYND10
# 184    up gene         KCNG2
# 185    up gene        MIR631
# 186    up gene       C8orf46
# 187    up gene      MLLT10P1
# 188    up gene       MIR6784
# 189    up gene       CCDC114
# 190    up gene          FGL2
# 191    up gene           GNN
# 192    up gene       TMEM240
# 193    up gene   RPS6KA2-IT1
# 194    up gene       MIR5690
# 195    up gene     LINC01473
# 196    up gene        FAM87B
# 197    up gene       MIR6737
# 198    up gene  LOC101929295
# 199    up gene  LOC101928516
# 200    up gene     BAALC-AS1
# 201    up gene         FCGBP
# 202    up gene          GRM4
# 203    up gene         TFPI2
# 204    up gene        LRRC32
# 205    up gene        ZNF205
# 206    up gene          AHSG
# 207    up gene          RTL1
# 208    up gene    LHFPL3-AS2
# 209    up gene        CARD14
# 210    up gene      C9orf106
# 211    up gene         MDH1B
# 212    up gene         CCRL2
# 213    up gene       C1orf61
# 214    up gene       SNORD70
# 215    up gene          EBI3
# 216    up gene       MIR6514
# 217    up gene         HOXD3
# 218    up gene          NME8
# 219    up gene        PLA2G7
# 220    up gene     MRVI1-AS1
# 221    up gene     LINC00552
# 222    up gene         SALL4
# 223    up gene          RELN
# 224    up gene          AMOT
# 225    up gene       MIR4677
# 226    up gene       MIR3960
# 227    up gene  LOC101927583
# 228    up gene         CCL22
# 229    up gene         KCNN1
# 230    up gene     MIR3648-1
# 231    up gene       SLC39A2
# 232       both         CD226
# 233    up gene          HIC1
# 234    up gene       MIR4746
# 235    up gene      SMC5-AS1
# 236    up gene        SLAMF1
# 237    up gene    CALML3-AS1
# 238    up gene     HIST1H2BJ
# 239    up gene     LINC00514
# 240    up gene     P4HA2-AS1
# 241    up gene       MIR6785
# 242       both         RFPL3
# 243    up gene      RNVU1-19
# 244    up gene       SNORA58
# 245    up gene     LINC00167
# 246    up gene          CCL4
# 247    up gene         WDR93
# 248    up gene    PARD6G-AS1
# 249    up gene        LEFTY1
# 250    up gene           SHH
# 251    up gene     LINC00891
# 252    up gene  LOC100132741
# 253    up gene          SYN2
# 254    up gene        TSPAN1
# 255    up gene     LOC154449
# 256    up gene    SNORD114-3
# 257    up gene        RNF217
# 258    up gene         ACRBP
# 259    up gene        CES1P1
# 260    up gene         CXCR6
# 261    up gene        NKX2-3
# 262    up gene     CECR5-AS1
# 263    up gene      SCARNA17
# 264    up gene     LINC00539
# 265    up gene    GLYCTK-AS1
# 266    up gene         TTC16
# 267    up gene       ZNF658B
# 268    up gene         APH1B
# 269  down gene         SLIT1
# 270  down gene        ENTPD3
# 271  down gene  LOC100506207
# 272  down gene       FAM183A
# 273  down gene        PDGFRB
# 274  down gene        RBFOX3
# 275  down gene  PRICKLE2-AS1
# 276  down gene    PPP4R1-AS1
# 277  down gene         CAPN9
# 278  down gene          BAAT
# 279  down gene         ATP4A
# 280  down gene         N4BP3
# 281  down gene         PYGO1
# 282  down gene          LYG2
# 283  down gene     LINC00908
# 284  down gene       CCDC148
# 285  down gene       ROCK1P1
# 286  down gene     PRKG1-AS1
# 287  down gene         ZAR1L
# 288  down gene       MIR4754
# 289  down gene         MFAP4
# 290  down gene          ROS1
# 291  down gene        FBXO27
# 292  down gene       C5orf60
# 293  down gene        LEFTY2
# 294  down gene         LRFN1
# 295  down gene         SFTPB
# 296  down gene           CEL
# 297  down gene        ATP2B4
# 298  down gene           PZP
# 299  down gene         CMYA5
# 300  down gene         HSPA2
# 301  down gene        HOXC12
# 302  down gene       GOLGA8H
# 303  down gene    SNORD116-1
# 304  down gene          NAT2
# 305  down gene          HMX3
# 306  down gene       ATP5EP2
# 307  down gene         UNC5B
# 308  down gene  LOC100129216
# 309  down gene       PLA2G1B
# 310  down gene      PCDHB19P
# 311  down gene  LOC102577426
# 312  down gene   CACNA1G-AS1
# 313  down gene           AMH
# 314  down gene        SPRNP1
# 315  down gene        MIR635
# 316  down gene     LOC554206
# 317  down gene      LOC63930
# 318  down gene         NAPSB
# 319  down gene        CCDC11
# 320  down gene         SPON1
# 321  down gene      C22orf31
# 322  down gene     GOLGA6L7P
# 323       both        ADAM23
# 324  down gene  LOC100506674
# 325  down gene       GSN-AS1
# 326  down gene         CHRNG
# 327  down gene     LOC285819
# 328  down gene       MIR5586
# 329  down gene       MIR6741
# 330  down gene  LOC101927018
# 331  down gene       CNTNAP3
# 332  down gene         PCAT2
# 333  down gene  LOC100506679
# 334       both     CATIP-AS2
# 335  down gene         LCE1E
# 336  down gene  LOC100130417
# 337  down gene       FAM166B
# 338  down gene         SOGA3
# 339  down gene     LINC01021
# 340  down gene         NUGGC
# 341  down gene      C1orf111
# 342  down gene        DPRXP4
# 343  down gene          MPP2
# 344  down gene         MTUS2
# 345  down gene        GRIN2C
# 346  down gene         PDE2A
# 347  down gene      SNORD38B
# 348  down gene         REP15
# 349  down gene           MRO
# 350  down gene        HPCAL4
# 351  down gene          WNT4
# 352  down gene         CARD9
# 353  down gene      LOH12CR2
# 354  down gene       MIR4722
# 355  down gene           PAH
# 356  down gene         PDZD4
# 357  down gene       HSPA12B
# 358  down gene          MTAP
# 359  down gene        MIR623
# 360  down gene         GRIA1
# 361  down gene          ARL9
# 362  down gene         CNIH2
# 363  down gene          DLL1
# 364  down gene       C2orf73
# 365  down gene       UBE2E4P
# 366  down gene     RAMP2-AS1
# 367  down gene         THEM5
# 368  down gene      DNASE1L2
# 369  down gene         AXIN2
# 370  down gene        RFPL3S
# 371  down gene           DDO
# 372  down gene      HIST2H3D
# 373  down gene  LOC101929723
# 374  down gene        H2BFXP
# 375  down gene  LOC101928940
# 376  down gene         EPHA4
# 377  down gene         GALR2
# 378  down gene        BTBD18
# 379  down gene       TMEM253
# 380  down gene       ZNF705E
# 381  down gene         SLIT3
# 382  down gene          TLR9
# 383  down gene        DLGAP3
# 384  down gene     NPHP3-AS1
# 385  down gene  LOC100506178
# 386  down gene        FBXO39
# 387  down gene       MIR5188
# 388  down gene       MIR4639
# 389  down gene   LAMTOR5-AS1
# 390  down gene       MIR6877
# 391  down gene       MIR7856
# 392  down gene  LOC101060498
# 393  down gene     LINC01068
# 394  down gene       MYCBPAP
# 395  down gene          M1AP
# 396  down gene     LINC01305
# 397  down gene          C1RL
# 398  down gene       TM4SF18
# 399  down gene         WNT16
# 400  down gene           PDC
# 401  down gene     LINC00304
# 402  down gene          CDH5
# 403  down gene          SYN1
# 404  down gene         ARMC4
# 405  down gene         RNU12
# 406  down gene        FCGR2B
# 407  down gene      HIST1H4J
# 408  down gene           NOG
# 409  down gene    ZRANB2-AS2
# 410  down gene         KCNE2
# 411  down gene         KRT6C
# 412  down gene     SATB2-AS1
# 413  down gene      KIAA1456
# 414  down gene         CASC1
# 415  down gene       MIR6792
# 416  down gene       FAM19A4
# 417  down gene       MIR6843
# 418  down gene      C15orf56
# 419  down gene          LRP2
# 420  down gene       HSD17B3
# 421  down gene         RAPSN
# 422  down gene    ZNF341-AS1
# 423  down gene        ZNF844
# 424  down gene        TM4SF1
# 425  down gene        SEMA3G
# 426  down gene          KRT5
# 427  down gene         CMTM7
# 428  down gene       PIK3AP1
# 429  down gene          ASIP
# 430  down gene        ST13P4
# 431  down gene       PGLYRP1
# 432  down gene         FOXR1
# 433  down gene         TEX15
# 434  down gene        MIR454
# 435  down gene      FLJ12825
# 436  down gene          DRD4
# 437  down gene          NOD2
# 438  down gene       MIR6829
# 439  down gene     RMDN2-AS1
# 440  down gene  LOC100507377
# 441  down gene    DNAH17-AS1
# 442  down gene       MIR6750
# 443  down gene       MIR6819
# 444  down gene     PARD3-AS1
# 445  down gene  LOC101927257
# 446  down gene  LOC102724190
# 447       both  LOC102724596
# 448  down gene     LCMT1-AS1
# 449  down gene        SPINK1
# 450  down gene         DNAH7
# 451  down gene      TCTEX1D4
# 452  down gene         CELA1
# 453  down gene     GRTP1-AS1
# 454  down gene        PLXNB3
# 455  down gene         TRIM2
# 456  down gene         PLAC1
# 457  down gene         LRTM2
# 458  down gene       SNORA19
# 459  down gene          PKP3
# 460  down gene       NEUROD1
# 461  down gene          TGM4
# 462  down gene         DDX43
# 463  down gene          RTN1
# 464  down gene          RGS1
# 465  down gene         SCN5A
# 466  down gene          MUC6
# 467  down gene        FERMT2
# 468  down gene          LIPM
# 469  down gene          CPB2
# 470  down gene      C1orf100
# 471  down gene          SGCE
# 472  down gene         THSD4
# 473  down gene        CLEC7A
# 474  down gene          VCAN
# 475  down gene         ESRRB
# 476  down gene        ADHFE1
# 477  down gene       TMSB15A
# 478  down gene         ASPDH
# 479  down gene      CATSPER1
# 480  down gene       MIR1469
# 481  down gene         NR2E3
# 482  down gene     LINC01412
# 483  down gene         BEST2
# 484  down gene    SRD5A3-AS1
# 485  down gene       FAM157A
# 486  down gene          OCA2
# 487  down gene           HPD
# 488  down gene         CNTD2
# 489  down gene       SNORA49
# 490  down gene        ERICH5
# 491  down gene       ZNF890P
# 492  down gene     LINC01251
# 493  down gene        TRIM73
# 494  down gene          NFIA
# 495  down gene  LOC101927740
# 496  down gene        TRIM74
# 497  down gene         FOXN4
# 498  down gene         KCNA3
# 499  down gene       MIR4668
# 500  down gene        AKR1C1
# 501  down gene      MIR199A1
# 502  down gene      AKR7A2P1
# 503  down gene         TENM4
# 504  down gene         IL17B
# 505  down gene          INGX
# 506  down gene     LINC00282
# 507  down gene  LOC101928847
# 508  down gene         WDR49
# 509  down gene         SVEP1
# 510  down gene     LOC388849
# 511  down gene     LINC00506
# 512  down gene    RNF216-IT1
# 513  down gene  LOC102546226
# 514  down gene  LOC101929696
# 515  down gene       MIR6866
# 516  down gene  LOC101927770
# 517  down gene  LOC101929765
# 518  down gene           NMU
# 519  down gene     ITIH4-AS1

# %%
from bsonstream import KeyValueBSONInput
import csv
import bson 
import json
from bson import ObjectId
import numpy as np
from string import punctuation

def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

with open('file\cpcd-gse70138.bson', 'rb') as f:
    stream = KeyValueBSONInput(fh=f)
    for dict_data in stream:
        del dict_data['_id']
        #name of row in .csv
        name = str(dict_data['batch'])+'_' +str(dict_data['pert_id'])+'_' +str(dict_data['pert_dose'])
        #get rid of file that does not contian a list of genes
        if dict_data.get('upGenes') != None:
            output = np.zeros(len(gene_a), dtype=object);
            index = 0
            #comparing interested regulated gene set and file from .bson
            for i,b in zip(gene_a,type_gene):
                for j in dict_data.get('upGenes'):
                    if i == j and (b == 'up gene' or b == 'both'):
                        output[index] = '1'
                for y in dict_data.get('dnGenes'):
                    if i == y and (b == 'down gene' or b == 'both'):
                        output[index] = '-1'
                index = index +1       
            df_pd[name] = output
# Out:
# C:\Users\Arada\Miniconda\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: generator 'KeyValueBSONInput.reads' raised StopIteration

# %%
df_pd.to_csv('PY017_table.csv',  encoding='utf-8')
