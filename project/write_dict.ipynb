# %%
import json
import pandas as pd
from collections import Counter
import numpy as np


filename_u = 'all_up.csv'
filename_d = 'all_dn.csv'

df_u =  pd.read_csv(filename_u);
df_d =  pd.read_csv(filename_d);
upgene= set(df_u['gene'])
dngene= set(df_d['gene'])

my_list_compare = ['genes']
my_list_compare_w = []
my_list_compare_u = []
type_gene = []

for item_s in upgene:
    my_list_compare_w.append(item_s)
    my_list_compare_u.append(item_s)

for item in dngene:
    my_list_compare_w.append(item)


gene_list = Counter(my_list_compare_w).keys()
gene_count =Counter(my_list_compare_w).values()
gene_cu =Counter(my_list_compare_u).values()


gene = list(gene_list)
genec = list(gene_count)
geneu = list(gene_cu)

gene_a = []

for x in range(0,len(gene_count)):
    if genec[x] != 2:
        if x  <  sum(geneu): 
            type_gene.append('up gene')
            gene_a.append(gene[x])
        else: 
            type_gene.append('down gene')
            gene_a.append(gene[x])
    else:    
        type_gene.append('both')
        gene_a.append(gene[x])

    
df_pd = pd.DataFrame(data = type_gene, columns = ['type'])
df_pd['gene'] = gene_a
df_pd
# Out:
#            type          gene
# 0       up gene     BAALC-AS1
# 1       up gene      LRP4-AS1
# 2       up gene  LOC100507537
# 3       up gene  LOC100288974
# 4       up gene  LOC103171574
# ...         ...           ...
# 1498  down gene       MIR6829
# 1499  down gene          HOPX
# 1500  down gene        DIRAS1
# 1501  down gene       DDX11L9
# 1502  down gene        FAR2P2
#
# [1503 rows x 2 columns]

# %%
from bsonstream import KeyValueBSONInput
import csv
import bson 
import json
from bson import ObjectId
import numpy as np
from string import punctuation

def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

with open('file\cpcd-gse70138.bson', 'rb') as f:
    with open('PY010_table_02.csv', 'w') as csvfile:
        csv_columns = ['name', 'gene']
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        stream = KeyValueBSONInput(fh=f)
        for dict_data in stream:
            del dict_data['_id']
            #name of row in .csv
            name = str(dict_data['batch'])+'_' +str(dict_data['pert_id'])+'_' +str(dict_data['pert_dose'])
            gene_up = []
            gene_all = []
            #get rid of file that does not contian a list of genes
            if dict_data.get('upGenes') != None:
                #comparing interested regulated gene set and file from .bson
                for i,b in zip(gene_b,type_gene):
                    for j in dict_data.get('upGenes'):
                        if i == j and (b == 'up gene' or b == 'both'):
                            gene_up.append(j)
                    for y in dict_data.get('dnGenes'):
                        if i == y and (b == 'down gene' or b == 'both'):
                            gene_up.append('-1'+'_'+y)
                writer.writerow(dict({'name' : name,  'gene' : set(gene_up)}))
        writer.writerow(dict({'name' : "Py010", 'gene' : set(gene_b)}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-156402778b9a> in <module>
#      25             if dict_data.get('upGenes') != None:
#      26                 #comparing interested regulated gene set and file from .bson
# ---> 27                 for i,b in zip(gene_a,type_gene):
#      28                     for j in dict_data.get('upGenes'):
#      29                         if i == j and (b == 'up gene' or b == 'both'):
#
# NameError: name 'gene_a' is not defined

# %%
from bsonstream import KeyValueBSONInput
import csv
import bson 
import json
from bson import ObjectId
import numpy as np
from string import punctuation

def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

with open('file\cpcd-gse70138.bson', 'rb') as f:
    with open('PY010_table_02.csv', 'w') as csvfile:
        csv_columns = ['name', 'gene_map','gene_all','prob']
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        stream = KeyValueBSONInput(fh=f)
        for dict_data in stream:
            del dict_data['_id']
            #name of row in .csv
            name = str(dict_data['batch'])+'_' +str(dict_data['pert_id'])+'_' +str(dict_data['pert_dose'])
            gene_up = []
            gene_all = []
            #get rid of file that does not contian a list of genes
            if dict_data.get('upGenes') != None:
                #comparing interested regulated gene set and file from .bson
                for i in gene_b:
                    for j in dict_data.get('upGenes'):
                        if j != '-666':
                            gene_all.append(j)
                            if i == j :
                                gene_up.append(j)
                    for y in dict_data.get('dnGenes'):
                        if y != '-666':
                            gene_all.append(y)
                            if '-1'+'_'+i == y :
                                gene_up.append('-1'+'_'+y)
                writer.writerow(dict({'name' : name,  'gene_map' : set(gene_up), 'gene_all' : set(gene_all), 'prob': len( set(gene_up))/len( set(gene_all)) }))
        #writer.writerow(dict({'name' : "Py010", 'gene' : set(gene_b)}))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-9085cc6b4f4e> in <module>
#      36                             if '-1'+'_'+i == y :
#      37                                 gene_up.append('-1'+'_'+y)
# ---> 38                 writer.writerow(dict({'name' : name,  'gene_map' : set(gene_up), 'gene_all' : set(gene_all), 'prob': len( set(gene_up))/len( set(gene_all)) }))
#      39         #writer.writerow(dict({'name' : "Py010", 'gene' : set(gene_b)}))
#      40
#
# ZeroDivisionError: division by zero

# %%
filename_u = 'Up_PY010.csv'
filename_d = 'Down_PY010.csv'

df_u =  pd.read_csv(filename_u);
df_d =  pd.read_csv(filename_d);
upgene= set(df_u['gene'])
dngene= set(df_d['gene'])

my_list_compare = ['genes']
my_list_compare_w = []
my_list_compare_u = []
type_gene_b = []

for item_s in upgene:
    my_list_compare_w.append(item_s)
    my_list_compare_u.append(item_s)

for item in dngene:
    my_list_compare_w.append(item)


gene_list = Counter(my_list_compare_w).keys()
gene_count =Counter(my_list_compare_w).values()
gene_cu =Counter(my_list_compare_u).values()


gene = list(gene_list)
genec = list(gene_count)
geneu = list(gene_cu)

gene_b = []

for x in range(0,len(gene_count)):
    if genec[x] != 2:
        if x  <  sum(geneu): 
            type_gene_b.append('up gene')
            gene_b.append(gene[x])
        else: 
            type_gene_b.append('down gene')
            gene_b.append('-1'+'_'+gene[x])
    else:    
        type_gene_b.append('both')
        gene_b.append(gene[x])

gene_b
# Out:
# ['APLN',
#  'DYNC1I1',
#  'LOC344887',
#  'LOC100288974',
#  'SPTB',
#  'SLC26A11',
#  'BEND6',
#  'GOLGA8N',
#  'NTN3',
#  'MIR8085',
#  'WNT11',
#  'CDKN2B',
#  'CACNA1G-AS1',
#  'TNNC2',
#  'EGLN3',
#  'BAMBI',
#  'TRDN',
#  'EBI3',
#  'SLAMF9',
#  'IL1A',
#  'FBXL8',
#  'FNDC4',
#  'CCL22',
#  'PDX1',
#  'TRIM69',
#  'GABRA2',
#  'LINC00886',
#  'RET',
#  'CXCR6',
#  'MYOZ2',
#  'SPX',
#  'SLAMF1',
#  'CDKL4',
#  'ERICH2',
#  'TPTE2P1',
#  'IL21R',
#  'LSP1',
#  'TFPI2',
#  'MIR20A',
#  'RFX8',
#  'BMP2',
#  'SLC3A2',
#  'F13B',
#  'HDDC3',
#  'SHH',
#  'MIR146A',
#  'HIST2H3D',
#  'GSTP1',
#  'COL1A2',
#  'MIR6820',
#  'LGALS4',
#  'CLDN23',
#  'RAB3C',
#  'GDPD1',
#  'TIMP4',
#  'CYP4F11',
#  'LOC100505912',
#  'ABCA9',
#  'KCNN1',
#  'GLT8D2',
#  'VLDLR-AS1',
#  'LOC101927211',
#  'ASB2',
#  'LINC01123',
#  'LRGUK',
#  'CCDC71L',
#  'C12orf76',
#  'SMAD7',
#  'LOC101927559',
#  'BIN3-IT1',
#  'APOC4',
#  'UBE2E2',
#  'LANCL3',
#  'CILP',
#  'HTR2B',
#  'MIR6075',
#  'CCL4L1',
#  'CCL4',
#  'LOC100506083',
#  'CYP1B1',
#  'CKM',
#  'STK32B',
#  'TXK',
#  'PLCE1',
#  'EPGN',
#  'HCAR3',
#  'LOC102723544',
#  'VEGFA',
#  'MYOT',
#  'LOC101928812',
#  'PTGS2',
#  'MZB1',
#  'MIR7108',
#  'MIR9-2',
#  'MRPS31P5',
#  'FSIP1',
#  'FAM78A',
#  'MIR762',
#  'TAS2R4',
#  'SLC26A4',
#  'ELN',
#  'XIRP1',
#  'RAB20',
#  'PRSS54',
#  'ZNF827',
#  'LINC01395',
#  'IL12B',
#  'TRIB3',
#  'HOXD3',
#  'RHOV',
#  'RLBP1',
#  'CXCL8',
#  'GNG13',
#  'OSBP2',
#  'MIR6785',
#  'FOXQ1',
#  'TMEM51',
#  'AGXT',
#  'JAZF1',
#  'MIR199A1',
#  'LRRC32',
#  'FXYD2',
#  'KCNG3',
#  'RAB41',
#  'LOC286190',
#  'HDC',
#  'CHIT1',
#  'MIRLET7D',
#  'MIR6740',
#  'MIR3651',
#  'LIF',
#  'MPP7',
#  'FAIM3',
#  'PLA2G7',
#  'MIR6826',
#  'MIR6780B',
#  'CCDC37',
#  'MYL2',
#  'MID1IP1-AS1',
#  'RASSF1-AS1',
#  'MAP4K1',
#  'KCNAB3',
#  'SNORA84',
#  'HMSD',
#  'ADH1A',
#  'SLC7A5',
#  'PARD6G-AS1',
#  'MKRN9P',
#  'FAM110D',
#  'TPRXL',
#  'LOC729296',
#  'LOC100505915',
#  'RRAD',
#  'SNORD114-3',
#  'CNTNAP3',
#  'ZFAND2A',
#  'PCAT1',
#  'CDH13',
#  'MOB3B',
#  'ZNF449',
#  'RNVU1-19',
#  'GNAT1',
#  'MIR29C',
#  'LOC102724927',
#  'KCNN3',
#  'C5orf34',
#  'PART1',
#  'LINC00412',
#  'FGF18',
#  'MYO15A',
#  'ID1',
#  'NUDT14',
#  'PAK3',
#  'CYP1A1',
#  'OGN',
#  'TUSC3',
#  'FBXO24',
#  'IFT27',
#  'ARSI',
#  'STC1',
#  'PSAPL1',
#  'PRNCR1',
#  'TNFSF15',
#  'MIR3648-1',
#  'CEBPB',
#  'LOC100996255',
#  'LOC728175',
#  'MCHR1',
#  'GP5',
#  'TPH1',
#  'RUNX2',
#  'CFTR',
#  'MYZAP',
#  'FAXC',
#  'FUT1',
#  'HRH2',
#  'LOC101927136',
#  'F10',
#  'PLXNB3',
#  'ZNF295-AS1',
#  'PLAC8L1',
#  'ELAVL2',
#  'MIR3136',
#  'GJC2',
#  'SNORA13',
#  'MIR3176',
#  'CXCL2',
#  'MT1F',
#  'HIST1H2BO',
#  'HIST1H3B',
#  'MYBPC2',
#  'ESRRB',
#  'EPS8L1',
#  'TRIM54',
#  'SMIM22',
#  'LOC101928911',
#  'HIST1H2BJ',
#  'CCL4L2',
#  '-1_BRINP3',
#  '-1_EGR4',
#  '-1_MYPOP',
#  '-1_PDE2A',
#  '-1_THSD4',
#  '-1_MIR4668',
#  '-1_BTBD19',
#  '-1_NEUROD1',
#  '-1_MIR6743',
#  '-1_C1orf100',
#  '-1_SPRNP1',
#  '-1_LOC101929140',
#  '-1_PLAC1',
#  '-1_SLC26A2',
#  '-1_DSEL',
#  '-1_ITIH4-AS1',
#  '-1_ENTPD3',
#  '-1_AK5',
#  '-1_DKFZP434L187',
#  '-1_UBE2MP1',
#  '-1_SESN3',
#  '-1_TMEM130',
#  '-1_M1AP',
#  '-1_PABPC1L2B',
#  '-1_SLC2A3',
#  '-1_SH2D6',
#  '-1_LINC01412',
#  '-1_CES3',
#  '-1_DNAH7',
#  '-1_VCAN',
#  '-1_CASC10',
#  '-1_CD36',
#  '-1_PRSS37',
#  '-1_CXCR4',
#  '-1_CSNK1A1P1',
#  '-1_TRIM2',
#  '-1_MIR3960',
#  '-1_FGFBP1',
#  '-1_TUB',
#  '-1_PPAP2B',
#  '-1_CD14',
#  '-1_LIPM',
#  '-1_SRD5A3-AS1',
#  '-1_SNORA49',
#  '-1_ERICH5',
#  '-1_TNNT1',
#  '-1_IFT43',
#  '-1_LINC00957',
#  '-1_ELOVL3',
#  '-1_C8G',
#  '-1_UCN2',
#  '-1_LOC101927770',
#  '-1_NR4A1',
#  '-1_SVEP1',
#  '-1_SGK1',
#  '-1_CCDC116',
#  '-1_LOC101929765',
#  '-1_AMER1',
#  '-1_RNU12',
#  '-1_LOC102724596',
#  '-1_LOC100506281',
#  '-1_VILL',
#  '-1_MIR6755',
#  '-1_DPEP2',
#  '-1_SHROOM2',
#  '-1_LCN10',
#  '-1_PARD3-AS1',
#  '-1_SNCA',
#  '-1_MIR200C',
#  '-1_ISPD',
#  '-1_TFAMP1',
#  '-1_LINC00282',
#  '-1_SNORD67',
#  '-1_LOC101927280',
#  '-1_FAM89A',
#  '-1_MFAP4',
#  '-1_WEE2-AS1',
#  '-1_LOC102546226',
#  '-1_MIR6734',
#  '-1_FOXN4',
#  '-1_IL17B',
#  '-1_LOC100133985',
#  '-1_LINC01251',
#  '-1_CTGF',
#  '-1_CCDC144A',
#  '-1_ADHFE1',
#  '-1_CYP4B1',
#  '-1_LOC102724058',
#  '-1_RASSF5',
#  '-1_CYP21A1P',
#  '-1_PDE4B',
#  '-1_SLC29A1',
#  '-1_LCMT1-AS1',
#  '-1_IDH1-AS1',
#  '-1_SEC14L5',
#  '-1_NEXN',
#  '-1_HPD',
#  '-1_ASPRV1',
#  '-1_WDFY3-AS2',
#  '-1_DNAH1',
#  '-1_FLJ12825',
#  '-1_GPR176',
#  '-1_NOS2',
#  '-1_LOC101929696',
#  '-1_CLEC7A',
#  '-1_TENM4',
#  '-1_NHLH2',
#  '-1_MIR3153',
#  '-1_MIR2861',
#  '-1_DCHS2',
#  '-1_MUC6',
#  '-1_DDX43',
#  '-1_CASZ1',
#  '-1_FAM19A4',
#  '-1_AKR7A2P1',
#  '-1_PRICKLE1',
#  '-1_LOC100131626',
#  '-1_LEFTY2',
#  '-1_PDC',
#  '-1_ATP8B5P',
#  '-1_CPB2',
#  '-1_MIR639',
#  '-1_MIR6866',
#  '-1_GOLGA8R',
#  '-1_FAM180B',
#  '-1_RTN1',
#  '-1_FOXO6',
#  '-1_KCNE2',
#  '-1_SOX5',
#  '-1_SOX7',
#  '-1_PGBD5',
#  '-1_BEST2',
#  '-1_ALPI',
#  '-1_CELA1',
#  '-1_CNTD2',
#  '-1_NFIA',
#  '-1_RORC',
#  '-1_IL16',
#  '-1_PXYLP1',
#  '-1_NOL4L',
#  '-1_FAXDC2',
#  '-1_ADCY5',
#  '-1_TMEM139',
#  '-1_TCTEX1D4',
#  '-1_PDE7B',
#  '-1_MYLK3',
#  '-1_SNORA2B',
#  '-1_PGBD2',
#  '-1_LAMA2',
#  '-1_SDS',
#  '-1_LOC101927257',
#  '-1_SGCE',
#  '-1_RNF216-IT1',
#  '-1_ZBED8',
#  '-1_SYNPO',
#  '-1_LINC00506',
#  '-1_MLLT11',
#  '-1_FLJ13224',
#  '-1_CYP21A2',
#  '-1_KRT40',
#  '-1_WDR49',
#  '-1_LOC340017',
#  '-1_ASIP',
#  '-1_RAMP2',
#  '-1_COL6A6',
#  '-1_MIR6819',
#  '-1_TP53INP2',
#  '-1_SPNS3',
#  '-1_RASL11B',
#  '-1_DYSF',
#  '-1_TRIM74',
#  '-1_FBXO27',
#  '-1_DCAF4L1',
#  '-1_MAP3K14',
#  '-1_PWWP2B',
#  '-1_KCNA3',
#  '-1_RGS1',
#  '-1_SNORA19',
#  '-1_DKK1',
#  '-1_LOC339803',
#  '-1_ADAM23',
#  '-1_LYPD3',
#  '-1_LINC00908',
#  '-1_DFFB',
#  '-1_C2orf50',
#  '-1_SLC25A25-AS1',
#  '-1_ZNF844',
#  '-1_ZNF890P',
#  '-1_LRTM2',
#  '-1_GSTA1',
#  '-1_PAPLN',
#  '-1_CHI3L2',
#  '-1_AOX2P',
#  '-1_KCNIP3',
#  '-1_NUGGC',
#  '-1_TGM4',
#  '-1_OCA2',
#  '-1_INGX',
#  '-1_MIR141',
#  '-1_LHB',
#  '-1_FOXR1',
#  '-1_CATSPER1',
#  '-1_TMSB15A',
#  '-1_SPON1',
#  '-1_SATB2-AS1',
#  '-1_LRRTM2',
#  '-1_THRSP',
#  '-1_ZDHHC8P1',
#  '-1_MIR563',
#  '-1_PKP3',
#  '-1_NR2E3',
#  '-1_CYBRD1',
#  '-1_PPFIA2',
#  '-1_GRTP1-AS1',
#  '-1_CATIP-AS2',
#  '-1_LAMB3',
#  '-1_LOC102577426',
#  '-1_SEC16B',
#  '-1_HHIPL2',
#  '-1_LOC388849',
#  '-1_MIR6792',
#  '-1_WNT16',
#  '-1_LOC339059',
#  '-1_C22orf31',
#  '-1_LYG2',
#  '-1_AKR1C1',
#  '-1_ULBP1',
#  '-1_MIR1469',
#  '-1_FAM157A',
#  '-1_TCTN2',
#  '-1_TERC',
#  '-1_TBXAS1',
#  '-1_TRIM73',
#  '-1_NMU',
#  '-1_SRGAP3',
#  '-1_TIGD1',
#  '-1_FERMT2',
#  '-1_HAPLN3',
#  '-1_F2RL2',
#  '-1_LOC101927740',
#  '-1_LOC101928847',
#  '-1_SGIP1',
#  '-1_SCN5A',
#  '-1_ASPDH',
#  '-1_FCGR2B',
#  '-1_SSBP3',
#  '-1_LINC01135']
