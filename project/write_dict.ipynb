# %%
import json
import pandas as pd
from collections import Counter
import numpy as np


filename_u = 'Up_PY017.csv'
filename_d = 'Down_PY017.csv'

df_u =  pd.read_csv(filename_u);
df_d =  pd.read_csv(filename_d);
upgene= df_u['gene']
dngene= df_d['gene']

my_list_compare = ['genes']
my_list_compare_w = []
my_list_compare_u = []
type_gene = []

for item_s in upgene:
    my_list_compare_w.append(item_s)
    my_list_compare_u.append(item_s)

for item in dngene:
    my_list_compare_w.append(item)


gene_list = Counter(my_list_compare_w).keys()
gene_count =Counter(my_list_compare_w).values()
gene_cu =Counter(my_list_compare_u).values()


gene = list(gene_list)
genec = list(gene_count)
geneu = list(gene_cu)

gene_a = []

for x in range(0,len(gene_count)):
    if genec[x] != 2:
        if x  <  sum(geneu): 
            type_gene.append('up gene')
            gene_a.append(gene[x])
        else: 
            type_gene.append('down gene')
            gene_a.append(gene[x])
    else:    
        type_gene.append('both')
        gene_a.append(gene[x])

    
df_pd = pd.DataFrame(data = type_gene, columns = ['type'])
df_pd['gene'] = gene_a
df_pd
# Out:
#           type          gene
# 0      up gene       SNORA13
# 1      up gene        C9orf9
# 2      up gene        NLGN4Y
# 3      up gene      KIAA0319
# 4      up gene         GNG13
# ..         ...           ...
# 515  down gene       MIR6866
# 516  down gene  LOC101927770
# 517  down gene  LOC101929765
# 518  down gene           NMU
# 519  down gene     ITIH4-AS1
#
# [520 rows x 2 columns]

# %%
from bsonstream import KeyValueBSONInput
import csv
import bson 
import json
from bson import ObjectId
import numpy as np
from string import punctuation

def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

with open('file\cpcd-gse70138.bson', 'rb') as f:
    with open('PY017_table_03.csv', 'w') as csvfile:
        csv_columns = ['name', 'gene']
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        stream = KeyValueBSONInput(fh=f)
        for dict_data in stream:
            del dict_data['_id']
            #name of row in .csv
            name = str(dict_data['batch'])+'_' +str(dict_data['pert_id'])+'_' +str(dict_data['pert_dose'])
            gene_up = []
            gene_down = []
            #get rid of file that does not contian a list of genes
            if dict_data.get('upGenes') != None:
                #comparing interested regulated gene set and file from .bson
                for i,b in zip(gene_a,type_gene):
                    for j in dict_data.get('upGenes'):
                        if i == j and (b == 'up gene' or b == 'both'):
                            gene_up.append(j)
                    for y in dict_data.get('dnGenes'):
                        if i == y and (b == 'down gene' or b == 'both'):
                            gene_up.append(y)
                writer.writerow(dict({'name' : name,  'gene' : set(gene_up)}))
                #writer.writerow(dict({'name' : name, 'type' :  'dn', 'gene' : gene_down}))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-fd70ef1befb1> in <module>
#      16         writer.writeheader()
#      17         stream = KeyValueBSONInput(fh=f)
# ---> 18         for dict_data in stream:
#      19             del dict_data['_id']
#      20             #name of row in .csv
#
# ~\Miniconda\lib\site-packages\bsonstream\__init__.py in reads(self)
#      84             n = it.next
#      85         while 1:
# ---> 86             doc = n()
#      87             yield doc
#      88
#
# ~\Miniconda\lib\site-packages\bsonstream\__init__.py in _reads(self)
#      61         r = self._read
#      62         while 1:
# ---> 63             yield r()
#      64
#      65     def close(self):
#
# ~\Miniconda\lib\site-packages\bsonstream\__init__.py in _read(self)
#      28             size_bits = self.fh.read(4)
#      29             size = struct.unpack("<i", size_bits)[0] - 4 # BSON size byte includes itself
# ---> 30             data = size_bits + self.fh.read(size)
#      31             if len(data) != size + 4:
#      32                 raise struct.error("Unable to read expected BSON Chunk; " +
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-55572c27bb0e> in <module>
# ----> 1 dict({'name': name, 'type' : -1, 'gene' :1})
#
# NameError: name 'name' is not defined
