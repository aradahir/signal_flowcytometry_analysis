# %%
import json
import pandas as pd
from collections import Counter
import numpy as np


filename_u = 'all_up.csv'
filename_d = 'all_dn.csv'

df_u =  pd.read_csv(filename_u);
df_d =  pd.read_csv(filename_d);
upgene= set(df_u['gene'])
dngene= set(df_d['gene'])

my_list_compare = ['genes']
my_list_compare_w = []
my_list_compare_u = []
type_gene = []

for item_s in upgene:
    my_list_compare_w.append(item_s)
    my_list_compare_u.append(item_s)

for item in dngene:
    my_list_compare_w.append(item)


gene_list = Counter(my_list_compare_w).keys()
gene_count =Counter(my_list_compare_w).values()
gene_cu =Counter(my_list_compare_u).values()


gene = list(gene_list)
genec = list(gene_count)
geneu = list(gene_cu)

gene_a = []

for x in range(0,len(gene_count)):
    if genec[x] != 2:
        if x  <  sum(geneu): 
            type_gene.append('up gene')
            gene_a.append(gene[x])
        else: 
            type_gene.append('down gene')
            gene_a.append(gene[x])
    else:    
        type_gene.append('both')
        gene_a.append(gene[x])

    
df_pd = pd.DataFrame(data = type_gene, columns = ['type'])
df_pd['gene'] = gene_a
df_pd
# Out:
#            type          gene
# 0       up gene       RCAN3AS
# 1       up gene        MIR638
# 2       up gene        DNAH12
# 3          both         TNNC2
# 4       up gene     LOC643623
# ...         ...           ...
# 1498  down gene  LOC100132111
# 1499  down gene         NXPH3
# 1500  down gene       PLA2G1B
# 1501  down gene        MLLT11
# 1502  down gene       ANKRD35
#
# [1503 rows x 2 columns]

# %%
from bsonstream import KeyValueBSONInput
import csv
import bson 
import json
from bson import ObjectId
import numpy as np
from string import punctuation

def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

with open('file\cpcd-gse70138.bson', 'rb') as f:
    with open('PY017_table_05.csv', 'w') as csvfile:
        csv_columns = ['name', 'gene']
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        stream = KeyValueBSONInput(fh=f)
        for dict_data in stream:
            del dict_data['_id']
            #name of row in .csv
            name = str(dict_data['batch'])+'_' +str(dict_data['pert_id'])+'_' +str(dict_data['pert_dose'])
            gene_up = []
            gene_all = []
            #get rid of file that does not contian a list of genes
            if dict_data.get('upGenes') != None:
                #comparing interested regulated gene set and file from .bson
                for i,b in zip(gene_a,type_gene):
                    for j in dict_data.get('upGenes'):
                        if i == j and (b == 'up gene' or b == 'both'):
                            gene_up.append(j)
                    for y in dict_data.get('dnGenes'):
                        if i == y and (b == 'down gene' or b == 'both'):
                            gene_up.append('-1'+'_'+y)
                writer.writerow(dict({'name' : name,  'gene' : set(gene_up)}))
        writer.writerow(dict({'name' : "Py017", 'gene' : set(gene_b)}))
# Out:
# C:\Users\Arada\Miniconda\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: generator 'KeyValueBSONInput.reads' raised StopIteration

# %%
filename_u = 'Up_PY017.csv'
filename_d = 'Down_PY017.csv'

df_u =  pd.read_csv(filename_u);
df_d =  pd.read_csv(filename_d);
upgene= set(df_u['gene'])
dngene= set(df_d['gene'])

my_list_compare = ['genes']
my_list_compare_w = []
my_list_compare_u = []
type_gene_b = []

for item_s in upgene:
    my_list_compare_w.append(item_s)
    my_list_compare_u.append(item_s)

for item in dngene:
    my_list_compare_w.append(item)


gene_list = Counter(my_list_compare_w).keys()
gene_count =Counter(my_list_compare_w).values()
gene_cu =Counter(my_list_compare_u).values()


gene = list(gene_list)
genec = list(gene_count)
geneu = list(gene_cu)

gene_b = []

for x in range(0,len(gene_count)):
    if genec[x] != 2:
        if x  <  sum(geneu): 
            type_gene_b.append('up gene')
            gene_b.append(gene[x])
        else: 
            type_gene_b.append('down gene')
            gene_b.append('-1'+'_'+gene[x])
    else:    
        type_gene_b.append('both')
        gene_b.append(gene[x])

gene_b
# Out:
# ['RCAN3AS',
#  'DNAH12',
#  'TNNC2',
#  'CFTR',
#  'HOXD3',
#  'C1orf61',
#  'MIR4677',
#  'SNORD64',
#  'CYP1A1',
#  'MDH1B',
#  'LOC101927583',
#  'LINC00552',
#  'GLYCTK-AS1',
#  'HSPB9',
#  'FOXD4',
#  'DNAJA4',
#  'LOC101929657',
#  'LINC00704',
#  'PYY2',
#  'LOC102659288',
#  'CCDC114',
#  'KCNN1',
#  'LOC101928008',
#  'SCGN',
#  'KCNG3',
#  'DCSTAMP',
#  'WFDC10B',
#  'MPL',
#  'NLGN4Y',
#  'MIR4690',
#  'PARD6G-AS1',
#  'LOC102723439',
#  'MYL3',
#  'MIR5690',
#  'RFPL3',
#  'MIR3176',
#  'LOC100507091',
#  'ZMYND10',
#  'ARHGEF33',
#  'MIR8085',
#  'RGPD1',
#  'DNAH9',
#  'SH3PXD2A-AS1',
#  'SLC35G2',
#  'RPL21P44',
#  'ADCY10',
#  'TFPI2',
#  'MIR1915',
#  'RPS6KA2-IT1',
#  'LEF1',
#  'MIR643',
#  'MYH7',
#  'NTN3',
#  'PHOSPHO1',
#  'FCGBP',
#  'DNAJB3',
#  'KCNAB3',
#  'AHSG',
#  'COL1A2',
#  'PLCE1',
#  'RAB41',
#  'CASQ2',
#  'SNORA28',
#  'MIR3648-1',
#  'CARD14',
#  'LRRTM3',
#  'ADAM22',
#  'APBA1',
#  'NSD1',
#  'GNG13',
#  'LOC100506476',
#  'MIR7112',
#  'A1CF',
#  'GGT8P',
#  'ISM1-AS1',
#  'LINC00539',
#  'LRRC32',
#  'SMC5-AS1',
#  'RTL1',
#  'HIST1H2BJ',
#  'FAM133CP',
#  'TNFSF13B',
#  'MIR29C',
#  'ULBP1',
#  'MIR6784',
#  'SNORD114-3',
#  'GRK1',
#  'SPATA12',
#  'FAM87B',
#  'MIR631',
#  'CCDC168',
#  'MIR6820',
#  'ITGA4',
#  'GRIK2',
#  'TPRXL',
#  'MRVI1-AS1',
#  'KLHL30',
#  'ISL1',
#  'MIR106B',
#  'CCRL2',
#  'CCL22',
#  'GLIS3',
#  'DPYSL3',
#  'MAMDC2-AS1',
#  'AMZ1',
#  'PBOV1',
#  'APOC4',
#  'TRPM6',
#  'GLT8D2',
#  'NKX2-3',
#  'SLC16A11',
#  'SLC39A2',
#  'PRB3',
#  'MIR5088',
#  'LINC01473',
#  'IL1A',
#  'SLAMF1',
#  'P4HA2-AS1',
#  'MYL1',
#  'MYBPC2',
#  'PRR29',
#  'OR2B6',
#  'LOC101929295',
#  'CARD16',
#  'GNAT1',
#  'MID1IP1-AS1',
#  'CSRP3',
#  'SH2D6',
#  'SNORD70',
#  'SYN2',
#  'FUT1',
#  'PTGS1',
#  'ANXA10',
#  'SHH',
#  'ARAP3',
#  'PLA2G7',
#  'MYBPC1',
#  'MIR3960',
#  'SCARNA17',
#  'FITM1',
#  'MYH1',
#  'MIR612',
#  'KCNG2',
#  'BAALC-AS1',
#  'BOC',
#  'LINC00514',
#  'CES1P1',
#  'ANKRD63',
#  'BCL2L14',
#  'KIAA0319',
#  'CALML3-AS1',
#  'LINC00624',
#  'JPH3',
#  'FAM159B',
#  'HIST1H2AD',
#  'LOC154449',
#  'LOC102724601',
#  'SNORA58',
#  'MYOT',
#  'FOXD4L1',
#  'LOXL2',
#  'RRAD',
#  'MIR6785',
#  'GJA9',
#  'WDR93',
#  'TMEM240',
#  'TAS2R3',
#  'CTAGE9',
#  'LOC728024',
#  'OLFML2B',
#  'LEPREL2',
#  'C8orf46',
#  'F2RL2',
#  'TUBA3E',
#  'LOC101927901',
#  'RELN',
#  'GSTA7P',
#  'ACRBP',
#  'GJC3',
#  'LINC00999',
#  'MIR4726',
#  'SALL4',
#  'TSPAN1',
#  'TMEM40',
#  'MIR6514',
#  'PRSS12',
#  'GRM4',
#  'WEE2',
#  'FGL2',
#  'HIGD1B',
#  'NME8',
#  'MYH2',
#  'LRRC17',
#  'LGI4',
#  'MIR424',
#  'CKM',
#  'SKOR1',
#  'CLPSL2',
#  'C9orf9',
#  'TUSC3',
#  'CD226',
#  'RHOD',
#  'QRFP',
#  'RSPH4A',
#  'OSCAR',
#  'MIR140',
#  'NFAM1',
#  'LINC00167',
#  'LINC00891',
#  'PTPRM',
#  'CECR5-AS1',
#  'MIR4746',
#  'AQP7',
#  'MAP1LC3A',
#  'TEC',
#  'ACTA1',
#  'MIR6737',
#  'LOC389895',
#  'MIR133A1HG',
#  'HIC1',
#  'LOC101927870',
#  'MLLT10P1',
#  'AMOT',
#  'RLBP1',
#  'C19orf35',
#  'HTR2B',
#  'LHFPL3-AS2',
#  'AQP9',
#  'GAREML',
#  'TNFRSF13C',
#  'RNF217',
#  'RNVU1-19',
#  'EBI3',
#  'SNORA13',
#  'AQP8',
#  'ZNF205',
#  'LOC100132741',
#  'ZNF582-AS1',
#  'MIR6857',
#  'NCAN',
#  'TNNT3',
#  'GCNT3',
#  'CACNA2D2',
#  'MIR4749',
#  'BCL2L15',
#  'SNORD15A',
#  'XIRP2',
#  'LOC101928516',
#  'MPO',
#  'SOX5',
#  'AGXT',
#  'LOC100128770',
#  'CXCR6',
#  'GNN',
#  'FOXL2NB',
#  'C9orf106',
#  'ACAP1',
#  'KANSL1-AS1',
#  'LINC00659',
#  'RET',
#  'SLN',
#  'MIR4519',
#  'LEFTY1',
#  'MTRNR2L2',
#  'CCL4',
#  'SLC26A4',
#  '-1_REP15',
#  '-1_TENM4',
#  '-1_CHRNG',
#  '-1_UNC5B',
#  '-1_SFTPB',
#  '-1_LINC01068',
#  '-1_LCE1E',
#  '-1_EPHA4',
#  '-1_CELA1',
#  '-1_LOC388849',
#  '-1_LOC63930',
#  '-1_DPRXP4',
#  '-1_C2orf73',
#  '-1_HIST1H4J',
#  '-1_LINC00282',
#  '-1_HSD17B3',
#  '-1_LOC101929723',
#  '-1_MIR4639',
#  '-1_LCMT1-AS1',
#  '-1_SEMA3G',
#  '-1_NAPSB',
#  '-1_MIR6877',
#  '-1_FAM19A4',
#  '-1_SCN5A',
#  '-1_LRP2',
#  '-1_TMSB15A',
#  '-1_H2BFXP',
#  '-1_LOC101928940',
#  '-1_CCDC148',
#  '-1_DDO',
#  '-1_ZNF844',
#  '-1_KRT5',
#  '-1_BAAT',
#  '-1_SRD5A3-AS1',
#  '-1_RNF216-IT1',
#  '-1_ZNF705E',
#  '-1_LOC100506679',
#  '-1_NOD2',
#  '-1_FAM157A',
#  '-1_SOGA3',
#  '-1_CEL',
#  '-1_GALR2',
#  '-1_NPHP3-AS1',
#  '-1_ST13P4',
#  '-1_IL17B',
#  '-1_LOC101927257',
#  '-1_KIAA1456',
#  '-1_RBFOX3',
#  '-1_PAH',
#  '-1_ASIP',
#  '-1_FAM166B',
#  '-1_ZRANB2-AS2',
#  '-1_NR2E3',
#  '-1_HPCAL4',
#  '-1_TM4SF18',
#  '-1_MIR635',
#  '-1_CACNA1G-AS1',
#  '-1_THEM5',
#  '-1_MIR6829',
#  '-1_CARD9',
#  '-1_FOXN4',
#  '-1_WDR49',
#  '-1_CASC1',
#  '-1_RFPL3S',
#  '-1_PYGO1',
#  '-1_MIR4754',
#  '-1_PGLYRP1',
#  '-1_TMEM253',
#  '-1_SGCE',
#  '-1_CATSPER1',
#  '-1_C15orf56',
#  '-1_PDE2A',
#  '-1_LINC00304',
#  '-1_ROS1',
#  '-1_LOC554206',
#  '-1_MIR6843',
#  '-1_CPB2',
#  '-1_SNORA49',
#  '-1_KCNA3',
#  '-1_MIR454',
#  '-1_DRD4',
#  '-1_DDX43',
#  '-1_PCDHB19P',
#  '-1_TLR9',
#  '-1_TGM4',
#  '-1_ARMC4',
#  '-1_SPRNP1',
#  '-1_MRO',
#  '-1_MIR623',
#  '-1_PLAC1',
#  '-1_CLEC7A',
#  '-1_CAPN9',
#  '-1_GRIN2C',
#  '-1_PPP4R1-AS1',
#  '-1_DNAH7',
#  '-1_ATP2B4',
#  '-1_LOC100130417',
#  '-1_TEX15',
#  '-1_RTN1',
#  '-1_SLIT1',
#  '-1_MIR6750',
#  '-1_C1orf100',
#  '-1_WNT4',
#  '-1_TRIM2',
#  '-1_RGS1',
#  '-1_LIPM',
#  '-1_FBXO27',
#  '-1_MUC6',
#  '-1_TRIM74',
#  '-1_SATB2-AS1',
#  '-1_MIR5188',
#  '-1_MIR5586',
#  '-1_LINC01305',
#  '-1_ADAM23',
#  '-1_BTBD18',
#  '-1_SPON1',
#  '-1_PIK3AP1',
#  '-1_ENTPD3',
#  '-1_MYCBPAP',
#  '-1_MIR6792',
#  '-1_NFIA',
#  '-1_DNASE1L2',
#  '-1_GOLGA6L7P',
#  '-1_NUGGC',
#  '-1_INGX',
#  '-1_CATIP-AS2',
#  '-1_N4BP3',
#  '-1_FCGR2B',
#  '-1_SNORA19',
#  '-1_MIR4668',
#  '-1_MTUS2',
#  '-1_LOC101928847',
#  '-1_CNTD2',
#  '-1_TCTEX1D4',
#  '-1_LOC100506207',
#  '-1_MPP2',
#  '-1_VCAN',
#  '-1_AXIN2',
#  '-1_SNORD116-1',
#  '-1_CMTM7',
#  '-1_MIR1469',
#  '-1_C22orf31',
#  '-1_AKR7A2P1',
#  '-1_LOC101929696',
#  '-1_NMU',
#  '-1_SPINK1',
#  '-1_BEST2',
#  '-1_ZNF658B',
#  '-1_SLIT3',
#  '-1_TRIM73',
#  '-1_MFAP4',
#  '-1_GRIA1',
#  '-1_AMH',
#  '-1_ROCK1P1',
#  '-1_RAMP2-AS1',
#  '-1_GRTP1-AS1',
#  '-1_PDC',
#  '-1_TTC16',
#  '-1_ATP4A',
#  '-1_LOC100506674',
#  '-1_LOC100506178',
#  '-1_TM4SF1',
#  '-1_PZP',
#  '-1_HSPA12B',
#  '-1_RNU12',
#  '-1_CNIH2',
#  '-1_SVEP1',
#  '-1_LOC101929765',
#  '-1_LOC101927018',
#  '-1_LOC100507377',
#  '-1_SYN1',
#  '-1_MTAP',
#  '-1_LOC101927770',
#  '-1_PCAT2',
#  '-1_HSPA2',
#  '-1_KCNE2',
#  '-1_PARD3-AS1',
#  '-1_LINC00506',
#  '-1_LOC101060498',
#  '-1_CNTNAP3',
#  '-1_ZAR1L',
#  '-1_LOC101927740',
#  '-1_LEFTY2',
#  '-1_WNT16',
#  '-1_CCDC11',
#  '-1_LRTM2',
#  '-1_AKR1C1',
#  '-1_PDZD4',
#  '-1_HOXC12',
#  '-1_MIR4722',
#  '-1_LOC102577426',
#  '-1_LINC00908',
#  '-1_DLL1',
#  '-1_THSD4',
#  '-1_ADHFE1',
#  '-1_LRFN1',
#  '-1_SNORD38B',
#  '-1_UBE2E4P',
#  '-1_RMDN2-AS1',
#  '-1_LINC01021',
#  '-1_OCA2',
#  '-1_MIR199A1',
#  '-1_PRKG1-AS1',
#  '-1_ARL9',
#  '-1_CMYA5',
#  '-1_CDH5',
#  '-1_KRT6C',
#  '-1_FLJ12825',
#  '-1_DLGAP3',
#  '-1_LAMTOR5-AS1',
#  '-1_MIR7856',
#  '-1_LOH12CR2',
#  '-1_MIR6819',
#  '-1_NEUROD1',
#  '-1_FBXO39',
#  '-1_APH1B',
#  '-1_PLXNB3',
#  '-1_HMX3',
#  '-1_LOC102546226',
#  '-1_LYG2',
#  '-1_LOC102724190',
#  '-1_HIST2H3D',
#  '-1_GSN-AS1',
#  '-1_ZNF341-AS1',
#  '-1_M1AP',
#  '-1_LINC01412',
#  '-1_PDGFRB',
#  '-1_ERICH5',
#  '-1_MIR6741',
#  '-1_FAM183A',
#  '-1_NOG',
#  '-1_C5orf60',
#  '-1_RAPSN',
#  '-1_DNAH17-AS1',
#  '-1_FERMT2',
#  '-1_ESRRB',
#  '-1_ZNF890P',
#  '-1_MIR6866',
#  '-1_HPD',
#  '-1_C1orf111',
#  '-1_NAT2',
#  '-1_FOXR1',
#  '-1_GOLGA8H',
#  '-1_LOC100129216',
#  '-1_ASPDH',
#  '-1_PRICKLE2-AS1',
#  '-1_C1RL',
#  '-1_ATP5EP2',
#  '-1_PLA2G1B',
#  '-1_PKP3',
#  '-1_ITIH4-AS1',
#  '-1_LINC01251',
#  '-1_LOC102724596',
#  '-1_LOC285819']
